# %%
import math
class Solution:
    import math
    global result_dict
    result_dict = {1:[0,0], 2:[1,1], 3:[2,1], 4:[4,2]}

    

    def cost(self, n):
        
        if n in result_dict:
            return result_dict[n][0]
        
        if n <= 2: 
            return n-1;
        
        if n == 3:
            return 2;

        if n==4:
            return 4

        

# 6 3 5 

        if n >=5:
            # index = 1
            # re = n - index + self.cost(n - index - 1)
            # return re

            index = 1
            min_re = 2 ** 31
            while(index <= n//2+1):
                # print('%%%%%%%%%%')
                partition = n - index
                # print('The first guess:', partition)
                left_re = partition + self.cost(partition- 1)
                # print('The left side guess need cost:',left_re)
                # back_num = index
#                 guess_time = math.floor(math.log2(index))
                # print(guess_time)
                right_re = partition + result_dict[index][1] * partition + self.cost(index) 
                # print(partition,guess_time * index,self.cost(index) )
                # print('The right side guess need cost:',right_re)
                
                if n==62 and index == 15:
                    print('partition:',partition)
                    print('This index is {}, its right_result is {}, left result is {}, final'.format(index,
                                                                                                      right_re,
                                                                                                     left_re))

                if right_re > left_re:
                    flag = 'right'
                    temp = right_re
#                     final_guesstime = result_dict[index][1]+1
                    
                else:
                    flag = 'left'
                    temp = left_re
#                     final_guesstime = result_dict[partition- 1][1]+1

                if temp < min_re:
                    min_re = temp
                    best_index = index
                    best_right_re = right_re
                    best_left_re = left_re
                    best_flag = flag
                    
                    
                    left_guesstime = result_dict[partition- 1][1]
                    right_guesstime = result_dict[index][1]
                    final_guesstime = max(left_guesstime,right_guesstime)+1
                    
                    
                
                index += 1
            
            result_dict[n] = [min_re,final_guesstime]
            
            
            
            print('This N is {}, this index is {}, its right_result is {}, left result is {}, final chose {}'.format(n,
                                                                                                      best_index,
                                                                                                      best_right_re,
                                                                                                     best_left_re,
                                                                                                     best_flag
                                                                                                     ))
            index += 1

            return min_re

    def getMoneyAmount(self, n: int) -> int:
        """
        :type n: int
        :rtype: int
        """

        

        

        result = self.cost(n)

        print(result_dict)

        
            
             
        return result


    
            
            
             
            


        return 20

# %%
import time
t0 = time.time()
solu = Solution()
re = solu.getMoneyAmount(62)
t1 = time.time()
print('solu new:',re,t1-t0)
# Out:
# This N is 6, this index is 3, its right_result is 8, left result is 4, final chose right
# This N is 5, this index is 1, its right_result is 4, left result is 6, final chose left
# This N is 8, this index is 3, its right_result is 12, left result is 9, final chose right
# This N is 7, this index is 3, its right_result is 10, left result is 6, final chose right
# This N is 10, this index is 3, its right_result is 16, left result is 15, final chose right
# This N is 9, this index is 3, its right_result is 14, left result is 12, final chose right
# This N is 12, this index is 3, its right_result is 20, left result is 21, final chose left
# This N is 11, this index is 3, its right_result is 18, left result is 18, final chose left
# This N is 14, this index is 3, its right_result is 24, left result is 27, final chose left
# This N is 13, this index is 3, its right_result is 22, left result is 24, final chose left
# This N is 16, this index is 3, its right_result is 28, left result is 34, final chose left
# This N is 15, this index is 3, its right_result is 26, left result is 30, final chose left
# This N is 18, this index is 3, its right_result is 32, left result is 42, final chose left
# This N is 17, this index is 3, its right_result is 30, left result is 38, final chose left
# This N is 20, this index is 3, its right_result is 36, left result is 51, final chose left
# This N is 19, this index is 3, its right_result is 34, left result is 46, final chose left
# This N is 22, this index is 5, its right_result is 57, left result is 51, final chose right
# This N is 21, this index is 5, its right_result is 54, left result is 46, final chose right
# This N is 24, this index is 5, its right_result is 63, left result is 61, final chose right
# This N is 23, this index is 5, its right_result is 60, left result is 56, final chose right
# This N is 26, this index is 5, its right_result is 69, left result is 72, final chose left
# This N is 25, this index is 5, its right_result is 66, left result is 66, final chose left
# This N is 28, this index is 5, its right_result is 75, left result is 80, final chose left
# This N is 27, this index is 5, its right_result is 72, left result is 76, final chose left
# This N is 30, this index is 5, its right_result is 81, left result is 88, final chose left
# This N is 29, this index is 5, its right_result is 78, left result is 84, final chose left
# This N is 32, this index is 5, its right_result is 87, left result is 99, final chose left
# This N is 31, this index is 5, its right_result is 84, left result is 92, final chose left
# This N is 34, this index is 5, its right_result is 93, left result is 109, final chose left
# This N is 33, this index is 5, its right_result is 90, left result is 104, final chose left
# This N is 36, this index is 5, its right_result is 99, left result is 119, final chose left
# This N is 35, this index is 5, its right_result is 96, left result is 114, final chose left
# This N is 38, this index is 9, its right_result is 130, left result is 109, final chose right
# This N is 37, this index is 5, its right_result is 102, left result is 124, final chose left
# This N is 40, this index is 9, its right_result is 138, left result is 119, final chose right
# This N is 39, this index is 9, its right_result is 134, left result is 114, final chose right
# This N is 42, this index is 9, its right_result is 146, left result is 132, final chose right
# This N is 41, this index is 9, its right_result is 142, left result is 124, final chose right
# This N is 44, this index is 9, its right_result is 154, left result is 144, final chose right
# This N is 43, this index is 9, its right_result is 150, left result is 138, final chose right
# This N is 46, this index is 9, its right_result is 162, left result is 156, final chose right
# This N is 45, this index is 9, its right_result is 158, left result is 150, final chose right
# This N is 48, this index is 9, its right_result is 170, left result is 169, final chose right
# This N is 47, this index is 9, its right_result is 166, left result is 162, final chose right
# This N is 50, this index is 9, its right_result is 178, left result is 179, final chose left
# This N is 49, this index is 9, its right_result is 174, left result is 174, final chose left
# This N is 52, this index is 9, its right_result is 186, left result is 189, final chose left
# This N is 51, this index is 9, its right_result is 182, left result is 184, final chose left
# This N is 54, this index is 9, its right_result is 194, left result is 199, final chose left
# This N is 53, this index is 9, its right_result is 190, left result is 194, final chose left
# This N is 56, this index is 9, its right_result is 202, left result is 209, final chose left
# This N is 55, this index is 9, its right_result is 198, left result is 204, final chose left
# This N is 58, this index is 9, its right_result is 210, left result is 219, final chose left
# This N is 57, this index is 9, its right_result is 206, left result is 214, final chose left
# This N is 60, this index is 9, its right_result is 218, left result is 230, final chose left
# This N is 59, this index is 9, its right_result is 214, left result is 224, final chose left
# partition: 47
# This index is 15, its right_result is 265, left result is 209, final
# This N is 62, this index is 9, its right_result is 226, left result is 242, final chose left
# {1: [0, 0], 2: [1, 1], 3: [2, 1], 4: [4, 2], 6: [8, 3], 5: [6, 2], 8: [12, 3], 7: [10, 3], 10: [16, 4], 9: [14, 3], 12: [21, 4], 11: [18, 4], 14: [27, 4], 13: [24, 4], 16: [34, 4], 15: [30, 4], 18: [42, 5], 17: [38, 4], 20: [51, 5], 19: [46, 5], 22: [57, 5], 21: [54, 5], 24: [63, 5], 23: [60, 5], 26: [72, 5], 25: [66, 5], 28: [80, 5], 27: [76, 5], 30: [88, 5], 29: [84, 5], 32: [99, 5], 31: [92, 5], 34: [109, 6], 33: [104, 5], 36: [119, 6], 35: [114, 6], 38: [130, 6], 37: [124, 6], 40: [138, 6], 39: [134, 6], 42: [146, 6], 41: [142, 6], 44: [154, 6], 43: [150, 6], 46: [162, 6], 45: [158, 6], 48: [170, 6], 47: [166, 6], 50: [179, 6], 49: [174, 6], 52: [189, 6], 51: [184, 6], 54: [199, 6], 53: [194, 6], 56: [209, 6], 55: [204, 6], 58: [219, 6], 57: [214, 6], 60: [230, 6], 59: [224, 6], 62: [242, 6]}
# solu new: 242 0.007375001907348633

# %%
solu2 = Solution2()
re = solu2.getMoneyAmount(52)
t2 = time.time()
print('solu old:',re,t2-t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-72a8d0ec08aa> in <module>
#       1 solu2 = Solution2()
# ----> 2 re = solu2.getMoneyAmount(52)
#       3 t2 = time.time()
#       4 print('solu old:',re,t2-t1)
#
# <ipython-input-60-70243497aa5d> in getMoneyAmount(self, n)
#      74
#      75
# ---> 76         return self.cost(n)
#      77
#      78
#
# <ipython-input-60-70243497aa5d> in cost(self, n)
#      36                 partition = n - index
#      37                 # print('The first guess:', partition)
# ---> 38                 left_re = partition + self.cost(partition- 1)
#      39                 # print('The left side guess need cost:',left_re)
#      40                 # back_num = index
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
import math
class Solution2:
    import math
    global result_dict
    result_dict = {1:0, 2:1, 3:2, 4:3}

    

    def cost(self, n):
        
        if n in result_dict:
            return result_dict[n]
        
        if n <= 2: 
            return n-1;
        
        if n == 3:
            return 2;

        if n==4:
            return 4

        

# 6 3 5 

        if n >=5:
            # index = 1
            # re = n - index + self.cost(n - index - 1)
            # return re

            index = 1
            min_re = 2 ** 31
            while(index <= n//2):
                # print('%%%%%%%%%%')
                partition = n - index
                # print('The first guess:', partition)
                left_re = partition + self.cost(partition- 1)
                # print('The left side guess need cost:',left_re)
                # back_num = index
                guess_time = math.floor(math.log2(index))
                # print(guess_time)
                right_re = partition + guess_time * partition + self.cost(index) 
                # print(partition,guess_time * index,self.cost(index) )
                # print('The right side guess need cost:',right_re)

                if right_re > left_re:
                    temp = right_re
                else:
                    temp = left_re

                if temp < min_re:
                    min_re = temp
                
                index += 1
            
            result_dict[n] = min_re

            return min_re

    def getMoneyAmount(self, n: int) -> int:
        """
        :type n: int
        :rtype: int
        """

        

        

            

        
            
             
        return self.cost(n)


    
            
            
             
            


        return 20

# %%
solu2 = Solution2()
re = solu2.getMoneyAmount(10)
t2 = time.time()
print('solu old:',re,t2-t1)
# Out:
# solu old: 16 426.6227140426636

# %%
class Solution3:
    def getMoneyAmount(self, n: int) -> int:
        dp = [[0 for _ in range(n + 1)] for _ in range(n + 1)]
        for i in range(n):
            dp[i][i] = 0        #就一个数字，必然正确
            dp[i][i+1] = i      #就2个数字。猜小的
        
        for L in range (n, -1, -1):     #L依赖右侧
            for R in range(L + 1, n + 1):   #R依赖左侧
                tmp = float('inf')
                for mid in range(L, R):     #猜的数字
                    this = mid + max(dp[L][mid - 1],  dp[mid + 1][R])
                    if this<tmp and L==1 and R==n:
                        print(mid)
                    tmp = min(tmp, this)
                dp[L][R] = tmp

        return dp

solu3 = Solution3()
re = solu3.getMoneyAmount(3)
t2 = time.time()
# for i in range(1,63):
# #     print(i)
#     re = solu3.getMoneyAmount(i)
#     print(i,re)
    
re=solu3.getMoneyAmount(62)
re[48][62]
# Out:
# 1
# 2
# 1
# 47
# 175
