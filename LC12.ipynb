# %% [markdown]
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# Symbol       Value
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# For example, 2 is written as II in Roman numeral, just two one's added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# I can be placed before V (5) and X (10) to make 4 and 9.
# X can be placed before L (50) and C (100) to make 40 and 90.
# C can be placed before D (500) and M (1000) to make 400 and 900.
# Given an integer, convert it to a roman numeral.
#
#
#
# Example 1:
#
# Input: num = 3
# Output: "III"
# Example 2:
#
# Input: num = 4
# Output: "IV"
# Example 3:
#
# Input: num = 9
# Output: "IX"
# Example 4:
#
# Input: num = 58
# Output: "LVIII"
# Explanation: L = 50, V = 5, III = 3.
# Example 5:
#
# Input: num = 1994
# Output: "MCMXCIV"
# Explanation: M = 1000, CM = 900, XC = 90 and IV = 4.
#
#
# Constraints:
#
# 1 <= num <= 3999
#
# 来源：力扣（LeetCode）
# 链接：https://leetcode-cn.com/problems/integer-to-roman
# 著作权归领扣网络所有。商业转载请联系官方授权，非商业转载请注明出处。

# %%
# Official solution
# 执行用时：
# 116 ms
# , 在所有 Python 提交中击败了
# 79.46%
# 的用户
# 内存消耗：
# 12.9 MB
# , 在所有 Python 提交中击败了
# 69.98%
# 的用户

class Solution(object):
    def intToRoman(self, num):
        """
        :type num: int
        :rtype: str
        """
        base = [1000,500,100,50,10,5,1]
        pattern = ['M','D','C','L','X','V','I']
        index_before = -1
        string = ''
        for index in range(len(base)):
            temp = num // base[index]
            num = num - temp * base[index]
            if temp == 4:
                string = string[:-1] + pattern[index] + pattern[index-1]
            else:
                string = string + pattern[index] * temp
            index_before = index
        
        return string
     
#x = [I 1 V 5 X 10 L 50 C 100 D 500 M 1000]
solu = Solution()
print('*******')
print(solu.intToRoman(3))
print('*******')
print(solu.intToRoman(4))
print('*******')
print(solu.intToRoman(9))
print('*******')
print(solu.intToRoman(58))
print('*******')
print(solu.intToRoman(1994))
# Out:
# *******
# III
# *******
# IV
# *******
# IV
# *******
# LVIII
# *******
# MCDXIV

# %%
num = 17
num//10
# Out:
# 1

# %%
# 执行用时：
# 124 ms
# , 在所有 Python 提交中击败了
# 61.80%
# 的用户
# 内存消耗：
# 13.1 MB
# , 在所有 Python 提交中击败了
# 8.18%
# 的用户


# string methods
class Solution(object):
    def isPalindrome(self, x):
        """
        :type x: int
        :rtype: bool
        """
        if x == 0:
            return True
        if x < 0:
            return False
        
        str_x = str(x)
        
        if len(str_x) == 1:
            return True
        
        end = len(str_x) - 1
        start = 0
        
        while(start <= end):
            
            if str_x[end] == str_x[start]:
                pass
            else:
                return False
                
            start += 1
            end -= 1
        return True
    
solu = Solution()
print(solu.isPalindrome(121))
print(solu.isPalindrome(10))
print(solu.isPalindrome(-121))
print(solu.isPalindrome(-101))
# Out:
# True
# False
# False
# False

# %%
x = 1234567

num = []
count = 10
if x > 0:
    while(count>=0):
        temp = x // 10 ** count
        num.append(temp)
        x -= temp * 10 ** count
        count = count - 1

    rev = 0
    new_count = 0
    for i in range(len(num)):
        if num[i] == 0 and new_count == 0:
            continue
        else:
            rev += num[i] * 10 ** new_count
            new_count+=1
print(rev)
# Out:
# 7654321

# %%
x = 1234321
x // 100
x % 10

# 执行用时：
# 212 ms
# , 在所有 Python 提交中击败了
# 5.19%
# 的用户
# 内存消耗：
# 13.1 MB
# , 在所有 Python 提交中击败了
# 17.70%
# 的用户

class Solution(object):
    def isPalindrome(self, x):
        """
        :type x: int
        :rtype: bool
        """

        if x == 0:
            return True
        if x < 0 or x < -2**31 or x>2**31 -1:
            return False
        
        count = 10
        while(count >= 0):
            this_num = (x //10 ** count)%10
#             print(this_num)
            if this_num!= 0:
                break
            count-=1
        print('non zero numbers number:', count+1)


        start = 0
        end = count
        while(start <= end):
            start_num = (x //10 ** start)%10
            end_num = (x//10 ** end)%10
            if start_num == end_num:
                pass
            else:
                return False

            start += 1
            end -=1
        return True
    
solu = Solution()
print(solu.isPalindrome(121))
print(solu.isPalindrome(10))
print(solu.isPalindrome(-121))
print(solu.isPalindrome(-101))
# Out:
# non zero numbers number: 3
# True
# non zero numbers number: 2
# False
# False
# False
